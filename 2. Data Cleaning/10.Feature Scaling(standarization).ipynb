# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# By using real data - sklearn
dataset=pd.read_csv("student_habits_performance.csv")
dataset.head(6)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23     NaN                  0.0                 NaN
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 NaN
# 5      S1005   24    Male                  7.2                 1.3
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1           NaN                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5           NaN                   90.9          4.9
# 5            0.0            No                   82.9          7.4
#
# ...

# %%
dataset.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            3
# study_hours_per_day               0
# social_media_hours                3
# netflix_hours                     0
# part_time_job                     2
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      2
# exercise_frequency                0
# parental_education_level         93
# internet_quality                  2
# mental_health_rating              0
# extracurricular_participation     1
# exam_score                        0
# dtype: int64

# %%
# dataset["netflix_hours"].fillna(dataset["netflix_hours"].mean())

# %%
sns.distplot(dataset["netflix_hours"])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23144\3656471360.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["netflix_hours"])

# %%
dataset.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000          997.000000    1000.000000
# mean     20.4980              3.55010            2.503711       4.539700
# std       2.3081              1.46889            1.171309      31.001181
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.600000
# max      24.0000              8.30000            7.200000     500.500000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
# using scikit learn

ss=StandardScaler()
ss.fit(dataset[["netflix_hours"]])
# Out:
# StandardScaler()

# %%
ss_transData=ss.transform(dataset[["netflix_hours"]])
ss_transData
# Out:
# array([[-1.11009356e-01],
#        [-7.22817846e-02],
#        [-1.04554761e-01],
#        [-1.14236653e-01],
#        [-1.30373142e-01],
#        [-1.46509630e-01],
#        [-1.01327463e-01],
#        [-8.19636774e-02],
#        [-9.16455702e-02],
#        [-1.04554761e-01],
#        [-1.20691249e-01],
#        [-6.58271893e-02],
#        [-1.33600439e-01],
#        [-5.93725941e-02],
#        [-1.23918546e-01],
#        [-1.14236653e-01],
#        [-1.40055034e-01],
#        [-1.07782058e-01],
#        [-5.29179989e-02],
#        [-6.90544870e-02],
#        [-5.29179989e-02],
#        [-6.90544870e-02],
#        [-1.27145844e-01],
#        [-1.01327463e-01],
#        [-1.17463951e-01],
#        [-4.00088085e-02],
#        [-1.30373142e-01],
#        [-5.61452965e-02],
#        [-5.61452965e-02],
#        [ 6.33390397e+00],
#        [-1.04554761e-01],
#        [ 3.10015177e+00],
#        [-7.73583237e-03],
#        [-1.11009356e-01],
#        [-1.43282332e-01],
# ...

# %%
dataset["netflix_hours_ss"]=pd.DataFrame(ss_transData,columns=["x"])
dataset.head(6)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23     NaN                  0.0                 NaN
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 NaN
# 5      S1005   24    Male                  7.2                 1.3
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1           NaN                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5           NaN                   90.9          4.9
# 5            0.0            No                   82.9          7.4
#
# ...

# %%
# nature check -> same or different
plt.figure(figsize=(12,5))
plt.subplot(1,2,1) # (row, col, position)
plt.title("Before")
sns.distplot(dataset["netflix_hours_ss"])

plt.subplot(1,2,2)
plt.title("After")
sns.distplot(dataset["netflix_hours"])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23144\2240895925.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["netflix_hours_ss"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23144\2240895925.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
