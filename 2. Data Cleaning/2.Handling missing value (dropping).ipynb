# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"titanic.csv") # load dataset -> r- raw string
dataset.head(3) # to show data of 3 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset.shape # total row & col
# Out:
# (202, 10)

# %%
((891-202)/891)*100
# Out:
# 77.32884399551067

# %%
dataset.isnull().sum() # total null in per column
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Show the heatmap of missing values
sns.heatmap(dataset.isnull())
plt.title("Missing Values Heatmap")
plt.show()

# %%
 # drop columns where missing value presents, inplace -> True means only update old data
dataset.drop(columns=["Cabin"],inplace=True)

# %%
dataset.dropna(inplace=True) # drop rows where missing value presents
