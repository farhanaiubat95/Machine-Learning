# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv(r"Salary_Data.csv")
dataset.head(4)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
dataset.shape
# Out:
# (57, 3)

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
# train , test

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
# Model

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([5495.13296253, 2156.25966222])

# %%
lr.intercept_
# Out:
# np.float64(-11214.99311725315)

# %%
# y = m1*x1 + m2*x2 + ... + c

lr.predict(x_test)
# Out:
# array([ 40111.10604819,  54314.86470518,  47212.98537669,  63065.28392243,
#         56610.28249261, 125166.48389898, 119163.63116299,  48743.26390164,
#         81581.56190387,  62515.77062618,  90839.70089459,  47212.98537669])

# %%
# accuracy

lr.score(x_test,y_test)*100
# Out:
# 97.4079466039442
